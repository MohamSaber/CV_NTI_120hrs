# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization,Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
import kagglehub
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("alxmamaev/flowers-recognition")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/flowers-recognition

# %%
datagen = ImageDataGenerator(rescale=1./255,
                             rotation_range = 30,
                             width_shift_range = .1,
                             height_shift_range = .1,
                             shear_range = .1,
                             zoom_range = .3,
                             horizontal_flip = True,
                             validation_split = .2,
                             fill_mode = 'nearest')

# %%
train = datagen.flow_from_directory(
    '/kaggle/input/flowers-recognition',
    target_size=(128, 128),
    batch_size=32,
    class_mode='binary',
    subset='training',
    shuffle=True
)
# Out:
# Found 3454 images belonging to 1 classes.

# %%
val = datagen.flow_from_directory(
    '/kaggle/input/flowers-recognition',
    target_size=(128, 128),
    batch_size=32,
    class_mode='binary',
    subset='validation',
    shuffle=False
)
# Out:
# Found 863 images belonging to 1 classes.

# %%
model = Sequential([Input(shape=(128, 128, 3)),
                    Conv2D(32, (3, 3), activation='relu', padding='same'),
                    MaxPooling2D(2,2),
                    Conv2D(32, (3, 3), activation='relu', padding='same'),
                    MaxPooling2D(2, 2),
                    Flatten(),
                    Dense(16, activation='relu'),
                    Dense(8, activation='relu'),
                    Dense(100, activation='softmax')])

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 128, 128, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 32768)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 16)             │       524,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 100)            │           900 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 535,484 (2.04 MB)
#  Trainable params: 535,484 (2.04 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(train, epochs=10, validation_data=val)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 33s 267ms/step - accuracy: 0.8462 - loss: 0.5777 - val_accuracy: 1.0000 - val_loss: 9.6570e-07
# Epoch 2/10
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 233ms/step - accuracy: 1.0000 - loss: 1.0390e-06 - val_accuracy: 1.0000 - val_loss: 7.7389e-07
# Epoch 3/10
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 232ms/step - accuracy: 1.0000 - loss: 2.7793e-06 - val_accuracy: 1.0000 - val_loss: 1.9662e-06
# Epoch 4/10
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 236ms/step - accuracy: 1.0000 - loss: 6.0720e-06 - val_accuracy: 1.0000 - val_loss: 8.0249e-07
# Epoch 5/10
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 229ms/step - accuracy: 1.0000 - loss: 1.7893e-06 - val_accuracy: 1.0000 - val_loss: 7.4527e-07
# Epoch 6/10
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 41s 230ms/step - accuracy: 1.0000 - loss: 5.6343e-07 - val_accuracy: 1.0000 - val_loss: 4.3729e-07
# Epoch 7/10
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 232ms/step - accuracy: 1.0000 - loss: 3.4130e-06 - val_accuracy: 1.0000 - val_loss: 5.3734e-08
# Epoch 8/10
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 232ms/step - accuracy: 1.0000 - loss: 4.2480e-07 - val_accuracy: 1.0000 - val_loss: 9.7796e-08
# Epoch 9/10
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 231ms/step - accuracy: 1.0000 - loss: 1.2840e-07 - val_accuracy: 1.0000 - val_loss: 2.9932e-07
# Epoch 10/10
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 230ms/step - accuracy: 1.0000 - loss: 2.3798e-07 - val_accuracy: 1.0000 - val_loss: 3.2599e-08

# %%
model.save('my_model.keras')
